# %%
# %load_ext autoreload
# %autoreload 2

import sys; sys.path += ['./../']
import anndata as ad
from CardamomOT import (
    plot_results_rna_mixture, plot_results_rna_clean, plot_results_prot,
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
p = './../experimental_datasets/Semrau/'
# plot_results_rna_mixture('full', 1, p)
plot_results_rna_clean('full', 0, p, stim=1.0, prior=1.0, normtransform=False, logtransform=True)
plot_results_prot(1, p, stim=1.0, prior=1.0)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /Users/eventre/Documents/GitHub/CardamomOT/utils/../CardamomOT/tools/plot_results.py:54: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(rect=[0, 0.14, 1, 1])
# /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ... storing 'source' as categorical
# ... storing 'source' as categorical

# %%
p = './../experimental_datasets/Kameneva/'
# plot_results_rna_mixture('full', 0, p)
plot_results_rna_clean('full', 0, p, stim=0.2, prior=1.0, logtransform=True, normtransform=False)
plot_results_prot(1, p, stim=0.2, prior=1.0)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /Users/eventre/Documents/GitHub/CardamomOT/utils/../CardamomOT/tools/plot_results.py:54: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(rect=[0, 0.14, 1, 1])
# /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ... storing 'source' as categorical
# ... storing 'source' as categorical

# %%
p = './../experimental_datasets/Schiebinger/'
# plot_results_rna_mixture('train', 0, p)
plot_results_rna_clean('train', 0, p, stim=1.0, prior=1.0, logtransform=True, normtransform=False)
plot_results_prot(1, p, stim=1.0, prior=1.0)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /Users/eventre/Documents/GitHub/CardamomOT/utils/../CardamomOT/tools/plot_results.py:54: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(rect=[0, 0.14, 1, 1])
# /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ... storing 'source' as categorical
# ... storing 'source' as categorical
