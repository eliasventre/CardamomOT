# %%
# %load_ext autoreload
# %autoreload 2

import sys; sys.path += ['./../']
import anndata as ad
from CardamomOT import (
    plot_results_rna_mixture, plot_results_rna_clean, plot_results_prot,
)

# %%
p = './../experimental_datasets/Semrau/'
plot_results_rna_mixture('full', './../experimental_datasets/Semrau/')
plot_results_rna_clean(p, stim=1.0, prior=1.0, normtransform=False, logtransform=True)
plot_results_prot(p, stim=1.0, prior=1.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 p = './../experimental_datasets/Semrau/'
# ----> 2 plot_results_rna_mixture('full', './../experimental_datasets/Semrau/')
#       3 plot_results_rna_clean(p, stim=1.0, prior=1.0, normtransform=False, logtransform=True)
#       4 plot_results_prot(p, stim=1.0, prior=1.0)
#
# TypeError: plot_results_rna_mixture() missing 1 required positional argument: 'p'

# %%
p = './../experimental_datasets/Kameneva/'
# plot_results_rna_mixture('full', p)
plot_results_rna_clean(p, stim=1.0, prior=1.0, logtransform=True, normtransform=False)
plot_results_prot(p, stim=1.0, prior=1.0)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /var/folders/lj/409601z9289fp_pv32k6f3frf4h14r/T/ipykernel_61505/1327844567.py:270: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig1.tight_layout(rect=[0, 0.14, 1, 1])
# /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
p = './../experimental_datasets/Schiebinger/'
# plot_results_rna_mixture('train', 0, p)
plot_results_prot(p, stim=1.0, prior=1.0)
plot_results_rna_clean('train', p, stim=1.0, prior=1.0, logtransform=True, normtransform=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 p = './../experimental_datasets/Schiebinger/'
#       2 # plot_results_rna_mixture('train', 0, p)
# ----> 3 plot_results_prot(p, stim=1.0, prior=1.0)
#       4 plot_results_rna_clean('train', p, stim=1.0, prior=1.0, logtransform=True, normtransform=False)
#
# TypeError: plot_results_prot() missing 1 required positional argument: 'p'
