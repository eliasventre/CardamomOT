# %%
# %load_ext autoreload
# %autoreload 2

import sys; sys.path += ['./../']
import anndata as ad
from CardamomOT import (
    plot_results_rna_mixture, plot_results_rna_clean, plot_results_prot,
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
p = './../collaborations/Copycat_sc/'
plot_results_rna_mixture('train', p)
plot_results_rna_clean(p, stim=1.0, prior=1.0, normtransform=False, logtransform=True)
plot_results_prot(p, stim=1.0, prior=1.0)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 p = './../collaborations/Copycat_sc/'
# ----> 2 plot_results_rna_mixture('train', p)
#       3 plot_results_rna_clean(p, stim=1.0, prior=1.0, normtransform=False, logtransform=True)
#       4 plot_results_prot(p, stim=1.0, prior=1.0)
#
# File ~/Documents/GitHub/CardamomOT/utils/../CardamomOT/tools/plot_results_sim.py:185, in plot_results_rna_mixture(split, p, project_on_full, normtransform, logtransform)
#     183     _fit_umap(adatas, names, reference_idx=0, norm=normtransform, log=logtransform)
#     184 else:
# --> 185     _joint_umap(adatas, names, norm=normtransform, log=logtransform)
#     187 _plot_time_panel(adatas, names)
#     188 _plot_celltype_panel(adatas, names, class_order)
#
# File ~/Documents/GitHub/CardamomOT/utils/../CardamomOT/tools/plot_results_sim.py:132, in _joint_umap(adatas, names, norm, log)
#     130     sc.pp.log1p(adata_all)
#     131 X = adata_all.X.toarray() if scipy.sparse.issparse(adata_all.X) else adata_all.X
# --> 132 proj = reducer.fit(X)
#     133 adata_all.obsm["X_umap"] = proj.transform(X)
#     134 for name, A in zip(names, adatas):
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:2817, in UMAP.fit(self, X, y, ensure_all_finite, **kwargs)
#    2813 if self.transform_mode == "embedding":
#    2814     epochs = (
#    2815         self.n_epochs_list if self.n_epochs_list is not None else self.n_epochs
#    2816     )
# -> 2817     self.embedding_, aux_data = self._fit_embed_data(
#    2818         self._raw_data[index],
#    2819         epochs,
#    2820         init,
#    2821         random_state,  # JH why raw data?
#    2822         **kwargs,
#    2823     )
#    2825     if self.n_epochs_list is not None:
#    2826         if "embedding_list" not in aux_data:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:2872, in UMAP._fit_embed_data(self, X, n_epochs, init, random_state, **kwargs)
#    2867 def _fit_embed_data(self, X, n_epochs, init, random_state, **kwargs):
#    2868     """A method wrapper for simplicial_set_embedding that can be
#    2869     replaced by subclasses. Arbitrary keyword arguments can be passed
#    2870     through .fit() and .fit_transform().
#    2871     """
# -> 2872     return simplicial_set_embedding(
#    2873         X,
#    2874         self.graph_,
#    2875         self.n_components,
#    2876         self._initial_alpha,
#    2877         self._a,
#    2878         self._b,
#    2879         self.repulsion_strength,
#    2880         self.negative_sample_rate,
#    2881         n_epochs,
#    2882         init,
#    2883         random_state,
#    2884         self._input_distance_func,
#    2885         self._metric_kwds,
#    2886         self.densmap,
#    2887         self._densmap_kwds,
#    2888         self.output_dens,
#    2889         self._output_distance_func,
#    2890         self._output_metric_kwds,
#    2891         self.output_metric in ("euclidean", "l2"),
#    2892         self.random_state is None,
#    2893         self.verbose,
#    2894         tqdm_kwds=self.tqdm_kwds,
#    2895     )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1195, in simplicial_set_embedding(data, graph, n_components, initial_alpha, a, b, gamma, negative_sample_rate, n_epochs, init, random_state, metric, metric_kwds, densmap, densmap_kwds, output_dens, output_metric, output_metric_kwds, euclidean_output, parallel, verbose, tqdm_kwds)
#    1188 embedding = (
#    1189     10.0
#    1190     * (embedding - np.min(embedding, 0))
#    1191     / (np.max(embedding, 0) - np.min(embedding, 0))
#    1192 ).astype(np.float32, order="C")
#    1194 if euclidean_output:
# -> 1195     embedding = optimize_layout_euclidean(
#    1196         embedding,
#    1197         embedding,
#    1198         head,
#    1199         tail,
#    1200         n_epochs,
#    1201         n_vertices,
#    1202         epochs_per_sample,
#    1203         a,
#    1204         b,
#    1205         rng_state,
#    1206         gamma,
#    1207         initial_alpha,
#    1208         negative_sample_rate,
#    1209         parallel=parallel,
#    1210         verbose=verbose,
#    1211         densmap=densmap,
#    1212         densmap_kwds=densmap_kwds,
#    1213         tqdm_kwds=tqdm_kwds,
#    1214         move_other=True,
#    1215     )
#    1216 else:
#    1217     embedding = optimize_layout_generic(
#    1218         embedding,
#    1219         embedding,
#    (...)   1235         move_other=True,
#    1236     )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/layouts.py:401, in optimize_layout_euclidean(head_embedding, tail_embedding, head, tail, n_epochs, n_vertices, epochs_per_sample, a, b, rng_state, gamma, initial_alpha, negative_sample_rate, parallel, verbose, densmap, densmap_kwds, tqdm_kwds, move_other)
#     398     dens_re_mean = 0
#     399     dens_re_cov = 0
# --> 401 optimize_fn(
#     402     head_embedding,
#     403     tail_embedding,
#     404     head,
#     405     tail,
#     406     n_vertices,
#     407     epochs_per_sample,
#     408     a,
#     409     b,
#     410     rng_state_per_sample,
#     411     gamma,
#     412     dim,
#     413     move_other,
#     414     alpha,
#     415     epochs_per_negative_sample,
#     416     epoch_of_next_negative_sample,
#     417     epoch_of_next_sample,
#     418     n,
#     419     densmap_flag,
#     420     dens_phi_sum,
#     421     dens_re_sum,
#     422     dens_re_cov,
#     423     dens_re_std,
#     424     dens_re_mean,
#     425     dens_lambda,
#     426     dens_R,
#     427     dens_mu,
#     428     dens_mu_tot,
#     429 )
#     431 alpha = initial_alpha * (1.0 - (float(n) / float(n_epochs)))
#     433 if verbose and n % int(n_epochs / 10) == 0:
#
# KeyboardInterrupt:

# %%
p = './../experimental_datasets/Semrau/'
# plot_results_rna_mixture('full', p)
plot_results_rna_clean(p, stim=1.0, prior=1.0, normtransform=False, logtransform=True)
plot_results_prot(p, stim=1.0, prior=1.0)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /Users/eventre/Documents/GitHub/CardamomOT/utils/../CardamomOT/tools/plot_results_sim.py:54: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(rect=[0, 0.14, 1, 1])
# /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ... storing 'source' as categorical
# ... storing 'source' as categorical

# %%
p = './../experimental_datasets/Kameneva/'
# plot_results_rna_mixture('full', p)
plot_results_rna_clean(p, stim=0.2, prior=1.0, logtransform=True, normtransform=False)
plot_results_prot(p, stim=0.2, prior=1.0)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /Users/eventre/Documents/GitHub/CardamomOT/utils/../CardamomOT/tools/plot_results_sim.py:54: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(rect=[0, 0.14, 1, 1])
# /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ... storing 'source' as categorical
# ... storing 'source' as categorical

# %%
p = './../experimental_datasets/Schiebinger/'
# plot_results_rna_mixture('train', p)
plot_results_rna_clean(p, stim=1.0, prior=1.0, logtransform=True, normtransform=False)
plot_results_prot(p, stim=1.0, prior=1.0)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /Users/eventre/Documents/GitHub/CardamomOT/utils/../CardamomOT/tools/plot_results_sim.py:54: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(rect=[0, 0.14, 1, 1])
# /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ... storing 'source' as categorical
# ... storing 'source' as categorical

# %%
p = './../collaborations/orga_Olivier/'
# plot_results_rna_mixture('full', p, logtransform=True, normtransform=True)
plot_results_rna_clean(p, stim=0.22, prior=1.0, logtransform=True, normtransform=True)
plot_results_prot(p, stim=0.22, prior=1.0)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /Users/eventre/Documents/GitHub/CardamomOT/utils/../CardamomOT/tools/plot_results_sim.py:54: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(rect=[0, 0.14, 1, 1])
# /opt/homebrew/Caskroom/miniconda/base/envs/cardamom_light/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ... storing 'source' as categorical
# ... storing 'source' as categorical
